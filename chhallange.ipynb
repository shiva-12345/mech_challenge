# %%
#import pandas for reading the csv file
import pandas as pd

#read csv
pd.read_csv("cars_price.csv")
# Out:
#        Unnamed: 0           make           model  priceUSD  year  \
# 0               0          honda          accord       565  1993
# 1               1           ford          fusion      5550  2008
# 2               2         nissan           teana      8300  2008
# 3               3     volkswagen             fox      3300  2005
# 4               4         nissan         primera      2450  2002
# ...           ...            ...             ...       ...   ...
# 39995       39995           jeep  grand-cherokee     12500  2008
# 39996       39996        peugeot             607      4754  2001
# 39997       39997  mercedes-benz         c-klass      4000  1999
# 39998       39998         proton         persona      1200  1996
# 39999       39999  mercedes-benz        190-w201       744  1986
#
#           condition  mileage(kilometers) fuel_type  volume(cm3)     color  \
# 0      with mileage             960015.0    petrol       2000.0     black
# ...

# %%
#assign the csv file to data frame using group function
df = pd.read_csv("cars_price.csv")
#print df
df.head(5)
# Out:
#    Unnamed: 0        make    model  priceUSD  year     condition  \
# 0           0       honda   accord       565  1993  with mileage
# 1           1        ford   fusion      5550  2008  with mileage
# 2           2      nissan    teana      8300  2008  with mileage
# 3           3  volkswagen      fox      3300  2005  with mileage
# 4           4      nissan  primera      2450  2002   with damage
#
#    mileage(kilometers) fuel_type  volume(cm3)     color transmission  \
# 0             960015.0    petrol       2000.0     black    mechanics
# 1             172000.0    diesel       1400.0    silver    mechanics
# 2             223000.0    petrol       2500.0    purple         auto
# 3             140000.0    petrol       1200.0      blue    mechanics
# 4             413000.0    diesel       2200.0  burgundy    mechanics
#
#           drive_unit segment
# 0  front-wheel drive       D
# 1  front-wheel drive       M
# 2  front-wheel drive       D
# 3  front-wheel drive       A
# ...

# %%
#task 1: Use of proper function like groupby, to draw decisive factors from the data
gr = df.groupby("priceUSD")
gr.first()
# Out:
#           Unnamed: 0      make     model  year     condition  \
# priceUSD
# 95              8867    proton   persona  1997   with damage
# 100             8248    toyota   corolla  1988     for parts
# 119            17515  lada-vaz     21099  1992     for parts
# 120            29948      ford    sierra  1988     for parts
# 133             7193   renault        19  1992  with mileage
# ...              ...       ...       ...   ...           ...
# 161563         23996     tesla   model-x  2019  with mileage
# 170000          8073   porsche   cayenne  2018  with mileage
# 170477         19607   bentley  bentayga  2016  with mileage
# 190141         16701   bentley  mulsanne  2014  with mileage
# 195000         33169   bentley  bentayga  2016  with mileage
#
#           mileage(kilometers)   fuel_type  volume(cm3)     color transmission  \
# priceUSD
# 95                     1111.0      petrol       1600.0  burgundy    mechanics
# ...

# %%
#plot of priceUSD vs Mileage
df.plot(x = 'priceUSD', y = 'mileage(kilometers)')

# %%
#Same way for Price vs Year and segment vs price
df.plot(x = 'priceUSD', y = 'year')

# %%
df.plot(x = 'segment', y = 'priceUSD')

# %%
#importing the required libraries
import researchpy as rp
import scipy.stats as stats

# %%
rp.ttest(group1= df['priceUSD'][df['mileage(kilometers)']], group1_name= "priceUSD VS mileage(kilometers)", group2= df['priceUSD'][df['year']], group2_name= "priceUSD VS year", )
# Out:
# (                          Variable        N         Mean           SD  \
#  0  priceUSD VS mileage(kilometers)   3298.0  6917.034566  7331.078577
#  1                 priceUSD VS year  40000.0  6106.174700  3848.536195
#  2                         combined  43298.0  6167.937734  4221.596991
#
#             SE    95% Conf.     Interval
#  0  127.656387  6666.740760  7167.328372
#  1   19.242681  6068.458597  6143.890803
#  2   20.288169  6128.172542  6207.702926  ,
#                                    Independent t-test     results
#  0  Difference (priceUSD VS mileage(kilometers) - ...    810.8599
#  1                              Degrees of freedom =   43296.0000
#  2                                               t =      10.6157
#  3                           Two side test p value =       0.0000
#  4                          Difference < 0 p value =       1.0000
#  5                          Difference > 0 p value =       0.0000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-eff848db86e9> in <module>
# ----> 1 rp.ttest(group1= df['segment'][df['priceUSD']], group1_name= "segment VS priceUSD")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     941         if key_type == "integer":
#     942             if self.index.is_integer() or self.index.is_floating():
# --> 943                 return self.loc[key]
#     944             else:
#     945                 return self._get_values(key)
#
# ...
